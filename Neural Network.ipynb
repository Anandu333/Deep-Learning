# %%
import pandas as pd

# %%
df= pd.read_csv("E:\Data sets\insurance.csv")

# %%
df.head()
# Out:
#    age  affordibility  insurance
# 0   21              1          0
# 1   25              1          0
# 2   31              0          0
# 3   50              1          1
# 4   41              1          1

# %%
df.shape
# Out:
# (34, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            34 non-null     int64
#  1   affordibility  34 non-null     int64
#  2   insurance      34 non-null     int64
# dtypes: int64(3)
# memory usage: 948.0 bytes

# %%
 df.describe()
# Out:
#              age  affordibility  insurance
# count  34.000000      34.000000  34.000000
# mean   35.911765       0.558824   0.500000
# std    13.369725       0.503995   0.507519
# min    17.000000       0.000000   0.000000
# 25%    25.000000       0.000000   0.000000
# 50%    34.500000       1.000000   0.500000
# 75%    44.000000       1.000000   1.000000
# max    61.000000       1.000000   1.000000

# %%
df['age']= df['age'].replace(17,18)

# %%
df.head()
# Out:
#    age  affordibility  insurance
# 0   21              1          0
# 1   25              1          0
# 2   31              0          0
# 3   50              1          1
# 4   41              1          1

# %%
df['age']= df['age'].apply(lambda x: 18 if x<18 else x)

# %%
df.head()
# Out:
#    age  affordibility  insurance
# 0   21              1          0
# 1   25              1          0
# 2   31              0          0
# 3   50              1          1
# 4   41              1          1

# %%
X= df.drop('insurance',axis=1)

# %%
y= df.insurance

# %%
X.head()
# Out:
#    age  affordibility
# 0   21              1
# 1   25              1
# 2   31              0
# 3   50              1
# 4   41              1

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    1
# Name: insurance, dtype: int64

# %%
# scale the age into a particular range
from sklearn.preprocessing import MinMaxScaler

# %%
scaler= MinMaxScaler()

# %%
scaler.fit_transform(X)
# Out:
# array([[0.06976744, 1.        ],
#        [0.1627907 , 1.        ],
#        [0.30232558, 0.        ],
#        [0.74418605, 1.        ],
#        [0.53488372, 1.        ],
#        [0.39534884, 1.        ],
#        [1.        , 0.        ],
#        [0.86046512, 0.        ],
#        [0.02325581, 1.        ],
#        [0.11627907, 1.        ],
#        [0.09302326, 1.        ],
#        [0.53488372, 1.        ],
#        [0.60465116, 0.        ],
#        [1.        , 0.        ],
#        [0.86046512, 1.        ],
#        [0.25581395, 1.        ],
#        [0.30232558, 0.        ],
#        [0.48837209, 1.        ],
#        [0.8372093 , 1.        ],
#        [0.93023256, 1.        ],
#        [0.6744186 , 0.        ],
#        [0.48837209, 0.        ],
#        [0.37209302, 1.        ],
#        [0.25581395, 1.        ],
#        [0.06976744, 1.        ],
#        [0.02325581, 1.        ],
#        [0.18604651, 0.        ],
#        [0.51162791, 0.        ],
# ...

# %%
X['age']=X['age']/100
X['age']
# Out:
# 0     0.21
# 1     0.25
# 2     0.31
# 3     0.50
# 4     0.41
# 5     0.35
# 6     0.61
# 7     0.55
# 8     0.19
# 9     0.23
# 10    0.22
# 11    0.41
# 12    0.44
# 13    0.61
# 14    0.55
# 15    0.29
# 16    0.31
# 17    0.39
# 18    0.54
# 19    0.58
# 20    0.47
# 21    0.39
# 22    0.34
# 23    0.29
# 24    0.21
# 25    0.19
# 26    0.26
# 27    0.40
# 28    0.32
# 29    0.18
# 30    0.18
# 31    0.25
# 32    0.35
# 33    0.44
# Name: age, dtype: float64

# %%
#pip install tensorflow

# %%
# tensorflow and keras is used to create hindeen layer
import tensorflow as tf
# Out:
# WARNING:tensorflow:From C:\Users\ACER\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from tensorflow import keras

# %% [raw]
#   working of neural network
#
# create model
# input -2 columns in this dataset
# output
# y= mx+c = m1x1,m2x2+c - by default
# provide logistic eq   - by manual
# activation function(sigmoid)- logistic eq
# Loss Function= difference betw error and actual

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train.shape
# Out:
# (27, 2)

# %%
X_test.shape
# Out:
# (7, 2)

# %%
model= keras.Sequential([
    keras.layers.Dense(1, input_shape= (2,), activation= "sigmoid")
    
])
# Out:
# WARNING:tensorflow:From C:\Users\ACER\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
 model.compile(optimizer= 'adam',loss= "binary_crossentropy", metrics= ['Accuracy'] )
# Out:
# WARNING:tensorflow:From C:\Users\ACER\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(X_train,y_train,epochs=500)
# Out:
# Epoch 1/500
# WARNING:tensorflow:From C:\Users\ACER\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\ACER\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1/1 [==============================] - 2s 2s/step - loss: 0.6752 - Accuracy: 0.5185
# Epoch 2/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6750 - Accuracy: 0.5185
# Epoch 3/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6749 - Accuracy: 0.5185
# Epoch 4/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6747 - Accuracy: 0.5185
# Epoch 5/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6745 - Accuracy: 0.5185
# Epoch 6/500
# ...

# %%
model.evaluate(X_test,y_test)
# Out:
# 1/1 [==============================] - 0s 363ms/step - loss: 0.6558 - Accuracy: 0.5714
# [0.6558166146278381, 0.5714285969734192]

# %%
predicted=model.predict(X_test)
predicted
# Out:
# 1/1 [==============================] - 0s 182ms/step
# array([[0.42022383],
#        [0.49781695],
#        [0.5574134 ],
#        [0.51986665],
#        [0.39416742],
#        [0.39933583],
#        [0.554748  ]], dtype=float32)

# %%
predted= []
for i in predicted:
    if i > 0.5:
        predted.append(1)
    else:
        predted.append(0)

# %%
predted
# Out:
# [0, 0, 1, 1, 0, 0, 1]

# %%
from sklearn.metrics import confusion_matrix

# %%
cm= tf.math.confusion_matrix(labels= y_test, predictions= predted)

# %%
import seaborn as sns

# %%
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >
